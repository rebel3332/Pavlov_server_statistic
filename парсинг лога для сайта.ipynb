# %%
file_name = "Logs/Pavlov-backup-2023.03.07-01.59.21.log"
count = 0
with open(file_name, "r") as file:
    lines = file.readlines()
    for line in lines:
        if "StatManagerLog" in line:
            if "{" in line:
                print(f"|{line}|")
                count += 1
display(count)
# Out:
# |[2023.03.06-15.15.11:488][777]StatManagerLog: {
# |
# |[2023.03.06-15.16.04:923][233]StatManagerLog: {
# |
# |[2023.03.06-15.46.47:944][406]StatManagerLog: {
# |
# |[2023.03.06-16.03.11:070][997]StatManagerLog: {
# |
# |[2023.03.06-16.24.53:103][512]StatManagerLog: {
# |
# |[2023.03.06-16.56.24:194][395]StatManagerLog: {
# |
# |[2023.03.06-17.21.14:094][283]StatManagerLog: {
# |
# |[2023.03.06-17.40.49:955][886]StatManagerLog: {
# |
# |[2023.03.06-17.47.35:538][843]StatManagerLog: {
# |
# |[2023.03.06-18.50.26:048][884]StatManagerLog: {
# |
# 10

# %%
import json
file_name = "Logs/Pavlov-backup-2023.03.07-01.59.21.log"
count = 0
found_json = False
text_json = ""
statistic = []

with open(file_name, "r") as file:
    lines = file.readlines()
    for line in lines:
        if not found_json:
            if "StatManagerLog" in line:
                if "{" in line:
                    found_json = True
                    text_json = "{\"date\": \"" + line.split(":")[0].replace("[", "") + "\",\n"
                    count += 1
        elif found_json:
            if "StatManagerLog: End Stat Dump" in line:
                # print(text_json)
                # text_json += "}"
                found_json = False
                statistic.append(json.loads(text_json))
                # display(text_json)
            else:
                text_json = text_json + line

display(count)
# json.loads(text_json)
statistic
# Out:
# 10

# %%
statistic
# Out:
# [{'date': '2023.03.06-15.15.11',
#   'allStats': [{'uniqueId': '76561199118116858',
#     'playerName': '4uk',
#     'teamId': 1,
#     'stats': [{'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Kill', 'amount': 3},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Death', 'amount': 1},
#      {'statType': 'Experience', 'amount': 360}]},
#    {'uniqueId': '76561199336597182',
#     'playerName': 'MAPK',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 2}]},
#    {'uniqueId': '76561198908165416',
#     'playerName': 'volync',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 1}]}],
#   'MapLabel': 'santorini',
#   'GameMode': 'SND',
#   'PlayerCount': 5,
#   'bTeams': True,
#   'Team0Score': 0,
#   'Team1Score': 10},
#  {'date': '2023.03.06-15.16.04',
#   'allStats': [{'uniqueId': '76561198908165416',
#     'playerName': 'volync',
#     'teamId': 0,
#     'stats': [{'statType': 'TeamKill', 'amount': 1}]},
#    {'uniqueId': '76561198169310550',
#     'playerName': 'GonJA',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 1}]}],
#   'MapLabel': 'UGC2285640263',
#   'GameMode': 'SND',
#   'PlayerCount': 4,
#   'bTeams': True,
#   'Team0Score': 0,
#   'Team1Score': 0},
#  {'date': '2023.03.06-15.46.47',
#   'allStats': [{'uniqueId': '76561199118116858',
#     'playerName': '4uk',
#     'teamId': 1,
#     'stats': [{'statType': 'TeamKill', 'amount': 1},
#      {'statType': 'Kill', 'amount': 18},
#      {'statType': 'Death', 'amount': 13},
#      {'statType': 'BombPlanted', 'amount': 5},
#      {'statType': 'Headshot', 'amount': 6},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'BombDefused', 'amount': 3},
#      {'statType': 'Experience', 'amount': 2310}]},
#    {'uniqueId': '76561199336597182',
#     'playerName': 'MAPK',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 13},
#      {'statType': 'Assist', 'amount': 5},
#      {'statType': 'Kill', 'amount': 19},
#      {'statType': 'Headshot', 'amount': 6},
#      {'statType': 'BombDefused', 'amount': 1},
#      {'statType': 'BombPlanted', 'amount': 2},
#      {'statType': 'Experience', 'amount': 2235}]},
#    {'uniqueId': '76561198908165416',
#     'playerName': 'volync',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 5},
#      {'statType': 'Assist', 'amount': 4},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 210}]},
#    {'uniqueId': '76561198169310550',
#     'playerName': 'GonJA',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 21},
#      {'statType': 'Headshot', 'amount': 7},
#      {'statType': 'Death', 'amount': 14},
#      {'statType': 'BombDefused', 'amount': 2},
#      {'statType': 'Assist', 'amount': 7},
#      {'statType': 'BombPlanted', 'amount': 3},
#      {'statType': 'Experience', 'amount': 2595}]},
#    {'uniqueId': '76561198202581810',
#     'playerName': 'OwenVonk',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 4},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 175}]},
#    {'uniqueId': '76561198275322138',
#     'playerName': 'Epaza',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 3},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 175}]},
#    {'uniqueId': '76561198093606639',
#     'playerName': 'Lug1a',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 8},
#      {'statType': 'Assist', 'amount': 5},
#      {'statType': 'Kill', 'amount': 5},
#      {'statType': 'Experience', 'amount': 625}]},
#    {'uniqueId': '76561199007195955',
#     'playerName': 'kondiss',
#     'teamId': 1,
#     'stats': [{'statType': 'Assist', 'amount': 3},
#      {'statType': 'Death', 'amount': 7},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 175}]},
#    {'uniqueId': '76561199044939742',
#     'playerName': 'NoiseBoys Loafer',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 3},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'Death', 'amount': 4},
#      {'statType': 'Assist', 'amount': 2},
#      {'statType': 'Experience', 'amount': 370}]},
#    {'uniqueId': '76561198827179128',
#     'playerName': 'jac',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 5},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Kill', 'amount': 2},
#      {'statType': 'Experience', 'amount': 275}]},
#    {'uniqueId': '76561198149141209',
#     'playerName': 'REX80HD',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 1},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 135}]}],
#   'MapLabel': 'UGC2296746974',
#   'GameMode': 'SND',
#   'PlayerCount': 7,
#   'bTeams': True,
#   'Team0Score': 9,
#   'Team1Score': 10},
#  {'date': '2023.03.06-16.03.11',
#   'allStats': [{'uniqueId': '76561198169310550',
#     'playerName': 'GonJA',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 20},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'Death', 'amount': 6},
#      {'statType': 'Assist', 'amount': 2},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 2120}]},
#    {'uniqueId': '76561199104027848',
#     'playerName': 'Indian Windows tech Suport',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 3},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Experience', 'amount': 25}]},
#    {'uniqueId': '76561198093606639',
#     'playerName': 'Lug1a',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 10},
#      {'statType': 'Kill', 'amount': 3},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 385}]},
#    {'uniqueId': '76561198149141209',
#     'playerName': 'REX80HD',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 11},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 250}]},
#    {'uniqueId': '76561198827179128',
#     'playerName': 'jac',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 1},
#      {'statType': 'Death', 'amount': 10},
#      {'statType': 'Assist', 'amount': 4},
#      {'statType': 'TeamKill', 'amount': 2},
#      {'statType': 'Experience', 'amount': 150}]},
#    {'uniqueId': '76561199336597182',
#     'playerName': 'MAPK',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 4},
#      {'statType': 'Assist', 'amount': 8},
#      {'statType': 'Kill', 'amount': 12},
#      {'statType': 'Headshot', 'amount': 3},
#      {'statType': 'Experience', 'amount': 1430}]},
#    {'uniqueId': '76561199118116858',
#     'playerName': '4uk',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 10},
#      {'statType': 'Death', 'amount': 3},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1035}]},
#    {'uniqueId': '76561198845519148',
#     'playerName': 'Mylo',
#     'teamId': 0,
#     'stats': [{'statType': 'Assist', 'amount': 1},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 125}]},
#    {'uniqueId': '76561198072483182',
#     'playerName': 'Elk',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 6},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Kill', 'amount': 4},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 485}]},
#    {'uniqueId': '76561198208785845',
#     'playerName': 'Shikiizaso',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 6},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Kill', 'amount': 3},
#      {'statType': 'Experience', 'amount': 325}]},
#    {'uniqueId': '76561198361105914',
#     'playerName': 'darkchildren',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 3},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Experience', 'amount': 25}]}],
#   'MapLabel': 'UGC1695916905',
#   'GameMode': 'SND',
#   'PlayerCount': 9,
#   'bTeams': True,
#   'Team0Score': 10,
#   'Team1Score': 1},
#  {'date': '2023.03.06-16.24.53',
#   'allStats': [{'uniqueId': '76561198093606639',
#     'playerName': 'Lug1a',
#     'teamId': 1,
#     'stats': [{'statType': 'Assist', 'amount': 3},
#      {'statType': 'Death', 'amount': 6},
#      {'statType': 'Kill', 'amount': 2},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 285}]},
#    {'uniqueId': '76561198827179128',
#     'playerName': 'jac',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 9},
#      {'statType': 'Headshot', 'amount': 4},
#      {'statType': 'Death', 'amount': 5},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Experience', 'amount': 965}]},
#    {'uniqueId': '76561198208785845',
#     'playerName': 'Shikiizaso',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 7},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'Kill', 'amount': 7},
#      {'statType': 'Experience', 'amount': 850}]},
#    {'uniqueId': '76561198169310550',
#     'playerName': 'GonJA',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 23},
#      {'statType': 'Headshot', 'amount': 4},
#      {'statType': 'Assist', 'amount': 4},
#      {'statType': 'Death', 'amount': 12},
#      {'statType': 'BombPlanted', 'amount': 2},
#      {'statType': 'TeamKill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 2515}]},
#    {'uniqueId': '76561198361105914',
#     'playerName': 'darkchildren',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 12},
#      {'statType': 'Assist', 'amount': 8},
#      {'statType': 'Kill', 'amount': 5},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 770}]},
#    {'uniqueId': '76561199336597182',
#     'playerName': 'MAPK',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Death', 'amount': 4},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Experience', 'amount': 185}]},
#    {'uniqueId': '76561199118116858',
#     'playerName': '4uk',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 13},
#      {'statType': 'Assist', 'amount': 5},
#      {'statType': 'Kill', 'amount': 15},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1695}]},
#    {'uniqueId': '76561198041110495',
#     'playerName': 'HASP',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 7},
#      {'statType': 'Death', 'amount': 3},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 835}]},
#    {'uniqueId': '76561198020711396',
#     'playerName': 'Max',
#     'teamId': 1,
#     'stats': [{'statType': 'Assist', 'amount': 4},
#      {'statType': 'Kill', 'amount': 2},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Death', 'amount': 6},
#      {'statType': 'Experience', 'amount': 360}]},
#    {'uniqueId': '76561198037698717',
#     'playerName': 'Ispa',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 10},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Death', 'amount': 5},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1085}]},
#    {'uniqueId': '76561198072483182',
#     'playerName': 'Elk',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 8},
#      {'statType': 'Headshot', 'amount': 4},
#      {'statType': 'Death', 'amount': 6},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'Experience', 'amount': 990}]},
#    {'uniqueId': '76561198829309796',
#     'playerName': 'KaZaH2099',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 6},
#      {'statType': 'Assist', 'amount': 2},
#      {'statType': 'Experience', 'amount': 50}]},
#    {'uniqueId': '76561198869689639',
#     'playerName': 'MGNO.',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 6},
#      {'statType': 'Kill', 'amount': 2},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Experience', 'amount': 285}]},
#    {'uniqueId': '76561198354807360',
#     'playerName': 'Monster- TOP G',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 3},
#      {'statType': 'Assist', 'amount': 2},
#      {'statType': 'Experience', 'amount': 50}]}],
#   'MapLabel': 'UGC1664873782',
#   'GameMode': 'SND',
#   'PlayerCount': 9,
#   'bTeams': True,
#   'Team0Score': 10,
#   'Team1Score': 6},
#  {'date': '2023.03.06-16.56.24',
#   'allStats': [{'uniqueId': '76561198869689639',
#     'playerName': 'MGNO.',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 7},
#      {'statType': 'Death', 'amount': 9},
#      {'statType': 'Assist', 'amount': 3},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 785}]},
#    {'uniqueId': '76561198041110495',
#     'playerName': 'HASP',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 12},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'Kill', 'amount': 13},
#      {'statType': 'Headshot', 'amount': 6},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1560}]},
#    {'uniqueId': '76561198037698717',
#     'playerName': 'Ispa',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 21},
#      {'statType': 'BombPlanted', 'amount': 3},
#      {'statType': 'Death', 'amount': 11},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'TeamKill', 'amount': 1},
#      {'statType': 'BombDefused', 'amount': 2},
#      {'statType': 'Experience', 'amount': 2495}]},
#    {'uniqueId': '76561199118116858',
#     'playerName': '4uk',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 12},
#      {'statType': 'Headshot', 'amount': 6},
#      {'statType': 'Death', 'amount': 9},
#      {'statType': 'Assist', 'amount': 2},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1360}]},
#    {'uniqueId': '76561198829309796',
#     'playerName': 'KaZaH2099',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 16},
#      {'statType': 'Assist', 'amount': 8},
#      {'statType': 'TeamKill', 'amount': 1},
#      {'statType': 'Kill', 'amount': 4},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'Experience', 'amount': 595}]},
#    {'uniqueId': '76561197966370770',
#     'playerName': 'Aeon',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 2},
#      {'statType': 'Assist', 'amount': 2},
#      {'statType': 'Experience', 'amount': 50}]},
#    {'uniqueId': '76561198257278289',
#     'playerName': "Dramptil'",
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 5},
#      {'statType': 'Death', 'amount': 11},
#      {'statType': 'Assist', 'amount': 4},
#      {'statType': 'Experience', 'amount': 600}]},
#    {'uniqueId': '76561198809271733',
#     'playerName': 'h',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 2},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Experience', 'amount': 25}]},
#    {'uniqueId': '76561199070706490',
#     'playerName': 'Hamood',
#     'teamId': 0,
#     'stats': [{'statType': 'Assist', 'amount': 2},
#      {'statType': 'Death', 'amount': 3},
#      {'statType': 'Experience', 'amount': 50}]},
#    {'uniqueId': '76561198217105593',
#     'playerName': 'shoe',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Death', 'amount': 2},
#      {'statType': 'Experience', 'amount': 110}]},
#    {'uniqueId': '76561199336597182',
#     'playerName': 'MAPK',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 11},
#      {'statType': 'Assist', 'amount': 5},
#      {'statType': 'Death', 'amount': 5},
#      {'statType': 'BombPlanted', 'amount': 5},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1485}]},
#    {'uniqueId': '76561198289569616',
#     'playerName': '',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 1}]},
#    {'uniqueId': '76561199093918494',
#     'playerName': 'gferret',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 5},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'Death', 'amount': 3},
#      {'statType': 'Experience', 'amount': 520}]}],
#   'MapLabel': 'UGC2923047424',
#   'GameMode': 'SND',
#   'PlayerCount': 9,
#   'bTeams': True,
#   'Team0Score': 10,
#   'Team1Score': 8},
#  {'date': '2023.03.06-17.21.14',
#   'allStats': [{'uniqueId': '76561198037698717',
#     'playerName': 'Ispa',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 26},
#      {'statType': 'Headshot', 'amount': 7},
#      {'statType': 'BombPlanted', 'amount': 2},
#      {'statType': 'Death', 'amount': 10},
#      {'statType': 'Assist', 'amount': 10},
#      {'statType': 'Experience', 'amount': 3020}]},
#    {'uniqueId': '76561198041110495',
#     'playerName': 'HASP',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 12},
#      {'statType': 'Kill', 'amount': 13},
#      {'statType': 'Headshot', 'amount': 7},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'BombPlanted', 'amount': 4},
#      {'statType': 'Experience', 'amount': 1720}]},
#    {'uniqueId': '76561198992861482',
#     'playerName': 'Lormuso',
#     'teamId': 1,
#     'stats': [{'statType': 'Assist', 'amount': 1},
#      {'statType': 'Death', 'amount': 1},
#      {'statType': 'Experience', 'amount': 25}]},
#    {'uniqueId': '76561199093918494',
#     'playerName': 'gferret',
#     'teamId': 1,
#     'stats': [{'statType': 'Assist', 'amount': 5},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Kill', 'amount': 7},
#      {'statType': 'Death', 'amount': 12},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'BombDefused', 'amount': 1},
#      {'statType': 'Experience', 'amount': 945}]},
#    {'uniqueId': '76561198823027910',
#     'playerName': 'Zynxs',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 15},
#      {'statType': 'Assist', 'amount': 8},
#      {'statType': 'Kill', 'amount': 7},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'Experience', 'amount': 920}]},
#    {'uniqueId': '76561199079805365',
#     'playerName': 'Mclovin',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 10},
#      {'statType': 'Assist', 'amount': 4},
#      {'statType': 'Kill', 'amount': 6},
#      {'statType': 'TeamKill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 675}]},
#    {'uniqueId': '76561198124215249',
#     'playerName': 'Das DeSalle Desaster',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 5},
#      {'statType': 'Kill', 'amount': 2},
#      {'statType': 'Experience', 'amount': 200}]},
#    {'uniqueId': '76561198363503451',
#     'playerName': 'Gomer',
#     'teamId': 1,
#     'stats': [{'statType': 'Assist', 'amount': 5},
#      {'statType': 'Kill', 'amount': 2},
#      {'statType': 'Death', 'amount': 10},
#      {'statType': 'TeamKill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 300}]},
#    {'uniqueId': '76561197981102889',
#     'playerName': 'RantoL',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 10},
#      {'statType': 'Death', 'amount': 8},
#      {'statType': 'Assist', 'amount': 7},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1235}]},
#    {'uniqueId': '76561198038985309',
#     'playerName': 'CHINZIG',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 5},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 260}]},
#    {'uniqueId': '76561198084366355',
#     'playerName': 'Dovaglitch',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 13},
#      {'statType': 'Headshot', 'amount': 4},
#      {'statType': 'Death', 'amount': 8},
#      {'statType': 'Assist', 'amount': 5},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1515}]},
#    {'uniqueId': '76561198160704791',
#     'playerName': 'SteelFrame',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 14},
#      {'statType': 'Death', 'amount': 12},
#      {'statType': 'Assist', 'amount': 8},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1610}]},
#    {'uniqueId': '76561198849015318',
#     'playerName': 'Isaac',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 2},
#      {'statType': 'Death', 'amount': 8},
#      {'statType': 'Assist', 'amount': 6},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 360}]},
#    {'uniqueId': '76561198908165416',
#     'playerName': 'volync',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 9},
#      {'statType': 'Death', 'amount': 7},
#      {'statType': 'BombDefused', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'Assist', 'amount': 4},
#      {'statType': 'Experience', 'amount': 1070}]},
#    {'uniqueId': '76561197961656549',
#     'playerName': 'dzizer',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 4},
#      {'statType': 'Death', 'amount': 3},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 435}]},
#    {'uniqueId': '76561198191788299',
#     'playerName': 'IlLezzoDiTurno',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 3},
#      {'statType': 'Headshot', 'amount': 3},
#      {'statType': 'Death', 'amount': 1},
#      {'statType': 'Experience', 'amount': 330}]},
#    {'uniqueId': '76561197995706469',
#     'playerName': 'raiken',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 2},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 210}]}],
#   'MapLabel': 'UGC2923120999',
#   'GameMode': 'SND',
#   'PlayerCount': 11,
#   'bTeams': True,
#   'Team0Score': 10,
#   'Team1Score': 8},
#  {'date': '2023.03.06-17.40.49',
#   'allStats': [{'uniqueId': '76561198037698717',
#     'playerName': 'Ispa',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 11},
#      {'statType': 'Headshot', 'amount': 4},
#      {'statType': 'Death', 'amount': 5},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 1190}]},
#    {'uniqueId': '76561199062660125',
#     'playerName': 'Cherrymoon ',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 2},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'Kill', 'amount': 1},
#      {'statType': 'Experience', 'amount': 125}]},
#    {'uniqueId': '76561199093918494',
#     'playerName': 'gferret',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 1},
#      {'statType': 'Death', 'amount': 4},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Experience', 'amount': 175}]},
#    {'uniqueId': '76561198908165416',
#     'playerName': 'volync',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 14},
#      {'statType': 'Headshot', 'amount': 6},
#      {'statType': 'Assist', 'amount': 4},
#      {'statType': 'Death', 'amount': 6},
#      {'statType': 'Experience', 'amount': 1560}]},
#    {'uniqueId': '76561198041110495',
#     'playerName': 'HASP',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 9},
#      {'statType': 'Assist', 'amount': 2},
#      {'statType': 'Kill', 'amount': 2},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 260}]},
#    {'uniqueId': '76561198191788299',
#     'playerName': 'IlLezzoDiTurno',
#     'teamId': 1,
#     'stats': [{'statType': 'Kill', 'amount': 2},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Death', 'amount': 10},
#      {'statType': 'Assist', 'amount': 8},
#      {'statType': 'Experience', 'amount': 410}]},
#    {'uniqueId': '76561198084366355',
#     'playerName': 'Dovaglitch',
#     'teamId': 0,
#     'stats': [{'statType': 'Death', 'amount': 7},
#      {'statType': 'Assist', 'amount': 8},
#      {'statType': 'BombPlanted', 'amount': 2},
#      {'statType': 'Kill', 'amount': 4},
#      {'statType': 'Headshot', 'amount': 2},
#      {'statType': 'Experience', 'amount': 720}]},
#    {'uniqueId': '76561199128001896',
#     'playerName': '[LR] toadies',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 5},
#      {'statType': 'Headshot', 'amount': 4},
#      {'statType': 'Death', 'amount': 4},
#      {'statType': 'Experience', 'amount': 540}]},
#    {'uniqueId': '76561197981102889',
#     'playerName': 'RantoL',
#     'teamId': 0,
#     'stats': [{'statType': 'Assist', 'amount': 7},
#      {'statType': 'Kill', 'amount': 5},
#      {'statType': 'Death', 'amount': 8},
#      {'statType': 'Headshot', 'amount': 1},
#      {'statType': 'Experience', 'amount': 685}]},
#    {'uniqueId': '76561198068221886',
#     'playerName': 'Ninjakeks',
#     'teamId': 0,
#     'stats': [{'statType': 'Kill', 'amount': 9},
#      {'statType': 'Death', 'amount': 5},
#      {'statType': 'Assist', 'amount': 1},
#      {'statType': 'BombPlanted', 'amount': 1},
#      {'statType': 'Headshot', 'amount': 3},
#      {'statType': 'Experience', 'amount': 1005}]}],
#   'MapLabel': 'UGC1695916905',
#   'GameMode': 'SND',
#   'PlayerCount': 0,
#   'bTeams': True,
#   'Team0Score': 6,
#   'Team1Score': 10},
#  {'date': '2023.03.06-17.47.35',
#   'allStats': [{'uniqueId': '76561199163295903',
#     'playerName': 'tage.boman',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 1}]}],
#   'MapLabel': 'UGC1676961583',
#   'GameMode': 'SND',
#   'PlayerCount': 1,
#   'bTeams': True,
#   'Team0Score': 0,
#   'Team1Score': 3},
#  {'date': '2023.03.06-18.50.26',
#   'allStats': [{'uniqueId': '76561198837841409',
#     'playerName': 'trocadero1',
#     'teamId': 1,
#     'stats': [{'statType': 'Death', 'amount': 3}]}],
#   'MapLabel': 'UGC2923120999',
#   'GameMode': 'SND',
#   'PlayerCount': 1,
#   'bTeams': True,
#   'Team0Score': 0,
#   'Team1Score': 10}]

# %%
from flask import Flask, request, jsonify, render_template
from flask_json import FlaskJSON, JsonError, json_response, as_json

app = Flask(__name__)
# FlaskJSON(app)

# @app.route('/get_value')
@app.route('/', methods=['POST', 'GET'])
# @app.route('/index')
# @as_json
def get_value():
    # return dict(value=12)
    # return json.loads(text_json)
    # return jsonify(json.loads(text_json))
    # return render_template('index.html', data = json.loads(text_json))
    return render_template('index.html', data = "123")


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %%
import pandas as pd
games = pd.json_normalize(statistic)

# %%
games
# Out:
#                   date                                           allStats  \
# 0  2023.03.06-15.15.11  [{'uniqueId': '76561199118116858', 'playerName...
# 1  2023.03.06-15.16.04  [{'uniqueId': '76561198908165416', 'playerName...
# 2  2023.03.06-15.46.47  [{'uniqueId': '76561199118116858', 'playerName...
# 3  2023.03.06-16.03.11  [{'uniqueId': '76561198169310550', 'playerName...
# 4  2023.03.06-16.24.53  [{'uniqueId': '76561198093606639', 'playerName...
# 5  2023.03.06-16.56.24  [{'uniqueId': '76561198869689639', 'playerName...
# 6  2023.03.06-17.21.14  [{'uniqueId': '76561198037698717', 'playerName...
# 7  2023.03.06-17.40.49  [{'uniqueId': '76561198037698717', 'playerName...
# 8  2023.03.06-17.47.35  [{'uniqueId': '76561199163295903', 'playerName...
# 9  2023.03.06-18.50.26  [{'uniqueId': '76561198837841409', 'playerName...
#
#         MapLabel GameMode  PlayerCount  bTeams  Team0Score  Team1Score
# 0      santorini      SND            5    True           0          10
# 1  UGC2285640263      SND            4    True           0           0
# 2  UGC2296746974      SND            7    True           9          10
# 3  UGC1695916905      SND            9    True          10           1
# 4  UGC1664873782      SND            9    True          10           6
# 5  UGC2923047424      SND            9    True          10           8
# 6  UGC2923120999      SND           11    True          10           8
# 7  UGC1695916905      SND            0    True           6          10
# 8  UGC1676961583      SND            1    True           0           3
# 9  UGC2923120999      SND            1    True           0          10

# %%
players = pd.DataFrame(columns=['game_data', 'uniqueId', 'playerName', 'teamId', 'stats'])
for row in games.iterrows():
    new_player = pd.DataFrame(row[1]['allStats'])
    new_player['game_data'] = row[1]['date']
    players = pd.concat([players, new_player], axis=0)
games.drop(['allStats'], axis=1, inplace=True)
players
# Out:
#               game_data           uniqueId    playerName teamId  \
# 0   2023.03.06-15.15.11  76561199118116858           4uk      1
# 1   2023.03.06-15.15.11  76561199336597182          MAPK      0
# 2   2023.03.06-15.15.11  76561198908165416        volync      0
# 0   2023.03.06-15.16.04  76561198908165416        volync      0
# 1   2023.03.06-15.16.04  76561198169310550         GonJA      0
# ..                  ...                ...           ...    ...
# 7   2023.03.06-17.40.49  76561199128001896  [LR] toadies      0
# 8   2023.03.06-17.40.49  76561197981102889        RantoL      0
# 9   2023.03.06-17.40.49  76561198068221886     Ninjakeks      0
# 0   2023.03.06-17.47.35  76561199163295903    tage.boman      1
# 0   2023.03.06-18.50.26  76561198837841409    trocadero1      1
#
#                                                 stats
# 0   [{'statType': 'BombPlanted', 'amount': 1}, {'s...
# 1                [{'statType': 'Death', 'amount': 2}]
# 2                [{'statType': 'Death', 'amount': 1}]
# 0             [{'statType': 'TeamKill', 'amount': 1}]
# 1                [{'statType': 'Death', 'amount': 1}]
# ..                                                ...
# 7   [{'statType': 'Kill', 'amount': 5}, {'statType...
# 8   [{'statType': 'Assist', 'amount': 7}, {'statTy...
# 9   [{'statType': 'Kill', 'amount': 9}, {'statType...
# 0                [{'statType': 'Death', 'amount': 1}]
# 0                [{'statType': 'Death', 'amount': 3}]
#
# [83 rows x 5 columns]

# %%
status_list = ['BombPlanted', 'BombDefused', 'Kill', 'Headshot', 'Death', 'Experience', 'TeamKill', 'Assist']
for row in players.iterrows():
    # display(row[1]['stats'])
    player_stats = row[1]['stats']#.split("},")
    for stat in player_stats:
        # players.loc[row[0],'BombPlanted']
        # display(type(stat))
        for stat_name in status_list:
            if stat['statType'] == stat_name:
                # display("YES")
                players.loc[row[0], stat_name] = stat['amount']
players.drop(['stats'], axis=1, inplace=True)

# %%
players
# Out:
#               game_data           uniqueId    playerName teamId  BombPlanted  \
# 0   2023.03.06-15.15.11  76561199118116858           4uk      1          1.0
# 1   2023.03.06-15.15.11  76561199336597182          MAPK      0          4.0
# 2   2023.03.06-15.15.11  76561198908165416        volync      0          1.0
# 0   2023.03.06-15.16.04  76561198908165416        volync      0          1.0
# 1   2023.03.06-15.16.04  76561198169310550         GonJA      0          4.0
# ..                  ...                ...           ...    ...          ...
# 7   2023.03.06-17.40.49  76561199128001896  [LR] toadies      0          1.0
# 8   2023.03.06-17.40.49  76561197981102889        RantoL      0          1.0
# 9   2023.03.06-17.40.49  76561198068221886     Ninjakeks      0          1.0
# 0   2023.03.06-17.47.35  76561199163295903    tage.boman      1          1.0
# 0   2023.03.06-18.50.26  76561198837841409    trocadero1      1          1.0
#
#     Kill  Headshot  Death  Experience  TeamKill  Assist  BombDefused
# 0   11.0       4.0    3.0      1190.0       1.0    10.0          3.0
# 1    1.0       7.0    2.0       125.0       NaN     1.0          1.0
# 2    1.0       2.0    4.0       175.0       1.0     1.0          2.0
# 0   11.0       4.0    3.0      1190.0       1.0    10.0          3.0
# 1    1.0       7.0    2.0       125.0       NaN     1.0          1.0
# ..   ...       ...    ...         ...       ...     ...          ...
# 7    5.0       4.0    4.0       540.0       1.0     5.0          NaN
# 8    5.0       1.0    8.0       685.0       NaN     7.0          NaN
# 9    9.0       3.0    5.0      1005.0       NaN     1.0          NaN
# 0   11.0       4.0    3.0      1190.0       1.0    10.0          3.0
# 0   11.0       4.0    3.0      1190.0       1.0    10.0          3.0
#
# [83 rows x 12 columns]

# %%
players[players['game_data'] == '2023.03.06-15.15.11'].to_json(orient='records')
# Out:
# '[{"game_data":"2023.03.06-15.15.11","uniqueId":"76561199118116858","playerName":"4uk","teamId":1,"BombPlanted":1.0,"Kill":11.0,"Headshot":4.0,"Death":3.0,"Experience":1190.0,"TeamKill":1.0,"Assist":10.0,"BombDefused":3.0},{"game_data":"2023.03.06-15.15.11","uniqueId":"76561199336597182","playerName":"MAPK","teamId":0,"BombPlanted":4.0,"Kill":1.0,"Headshot":7.0,"Death":2.0,"Experience":125.0,"TeamKill":null,"Assist":1.0,"BombDefused":1.0},{"game_data":"2023.03.06-15.15.11","uniqueId":"76561198908165416","playerName":"volync","teamId":0,"BombPlanted":1.0,"Kill":1.0,"Headshot":2.0,"Death":4.0,"Experience":175.0,"TeamKill":1.0,"Assist":1.0,"BombDefused":2.0}]'

# %%
# players.to_json(orient='records')
# json.loads(players.set_index('game_data').to_json(orient='records'))
new_json = []
for game in games.iterrows():
    # display(game[1])
    new_rec_in_json = game[1]
    new_rec_in_json['allStats'] = json.loads(players[players['game_data'] == game[1]['date']].to_json(orient='records'))
    new_json.append(new_rec_in_json)
new_json
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 9
#       7     new_rec_in_json['allStats'] = players[players['game_data'] == game[1]['date']].to_json(orient='records')
#       8     new_json.append(new_rec_in_json)
# ----> 9 json.loads(new_json)
#
# File d:\Programs\Python\Python311\Lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not list
